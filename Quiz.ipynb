# %%
import pandas as pd
fuel_data = pd.read_csv(r'C:\Users\Dell\Desktop\fuel_ferc1.csv')
fuel_data.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel_data.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
fuel_data.kurt()
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64

# %%
fuel_data.skew()
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
fuel_data.groupby('fuel_cost_per_unit_delivered').first()
# Out:
#                                              record_id  utility_id_ferc1  \
# fuel_cost_per_unit_delivered
# -874.937                       f1_fuel_2008_12_177_1_1               177
# -488.054                       f1_fuel_2007_12_177_2_4               177
# -313.410                       f1_fuel_2004_12_210_1_6               210
# -174.670                      f1_fuel_2000_12_194_2_15               194
# -170.187                         f1_fuel_2015_12_6_1_2                 6
# ...                                                ...               ...
#  1942979.000                    f1_fuel_1997_12_9_0_14                 9
#  2114508.000                    f1_fuel_1996_12_9_0_14                 9
#  2255688.000                    f1_fuel_1997_12_9_0_11                 9
#  7793482.000                     f1_fuel_1996_12_9_0_8                 9
#  7964521.000                     f1_fuel_1997_12_9_0_8                 9
#
# ...

# %%
fuel_data.groupby('fuel_cost_per_unit_burned').first()
# Out:
#                                           record_id  utility_id_ferc1  \
# fuel_cost_per_unit_burned
# -276.080                    f1_fuel_2000_12_194_3_3               194
# -174.670                    f1_fuel_2000_12_194_3_6               194
# -123.310                   f1_fuel_2000_12_194_2_15               194
# -119.040                    f1_fuel_2003_12_281_1_4               281
# -85.760                     f1_fuel_1995_12_194_5_9               194
# ...                                             ...               ...
#  65137.588                   f1_fuel_2012_12_7_7_13                 7
#  69785.215                   f1_fuel_2011_12_7_7_13                 7
#  80459.000                  f1_fuel_2014_12_177_2_7               177
#  83538.000                  f1_fuel_2011_12_132_1_2               132
#  139358.000                 f1_fuel_2014_12_147_0_2               147
#
#                            report_year     plant_name_ferc1  \
# fuel_cost_per_unit_burned
# ...
